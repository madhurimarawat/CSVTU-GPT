# %% [markdown]
# # Web Scraping
# Web scraping is the process of **extracting data** from a website. It is an
# **automatic method** to obtain large amounts of data from websites . Most of this data is **unstructured data** in an HTML format which is then converted into structured data in a spreadsheet or a database so that it can be used in various applications . There are many different ways to perform web scraping to obtain data from websites. These include using online services, particular API’s or even creating your code for web scraping from scratch .
#
# Web scraping requires two parts, namely the **crawler** and the **scraper**. The crawler is an artificial intelligence algorithm that browses the web to search for the particular data required by following the links across the internet. The scraper, on the other hand, is a specific tool created to extract data from the website .

# %%
# Importing Required Libraries
# requests is used to get access to the website or in other words connect to the website
import requests
# Beautiful Soup 4 is a Python library that makes it easy to scrape information from web pages. It provides Pythonic idioms for iterating, searching, and modifying the parse tree. The library sits atop an HTML or XML parser.
from bs4 import BeautifulSoup

# %% [markdown]
# ## Accessing/Scraping embedded links
# We cannot directly scrape a website content, first we will access all the embedded links and after that we can scrape data from the website.

# %%
# Send an HTTP request to the URL of the webpage we want to access
URL = "https://csvtu.ac.in/ew/"
r = requests.get(URL)

# Create a BeautifulSoup object and parse the HTML content
soup = BeautifulSoup(r.content, 'html.parser')

# Find all the links on the webpage
links = soup.find_all('a')

# Save the scraped data to a text file
with open('Embedded_links_csvtu.txt', 'w') as f:

   # Iterating through the links
    for link in links:

       # Creating an object and storing links
        href = link.get('href')

        # To ensure we are scraping the link
        if href is not None:

           # Writing links to text file
            f.write(href + '\n')

# %% [markdown]
# ## Getting the HTML code from the website
#
# If we want to access the HTML code of the website we can use this code:
#
# We need to install requests,html5lib and bs4 before running this code
#
# ```
# import requests
# URL = "https://csvtu.ac.in/ew/"
# r = requests.get(URL)
# print(r.content)
#
# # For getting the header component of the website
# headers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246"}
# # Here the user agent is for Edge browser on windows 10. You can find your browser user agent from the above given link.
# r = requests.get(url=URL, headers=headers)
# print(r.content)
#
# #This will not run on online IDE
# import requests
# from bs4 import BeautifulSoup
#
# URL = "https://csvtu.ac.in/ew/"
# r = requests.get(URL)
#
# soup = BeautifulSoup(r.content, 'html5lib') # If this line causes an error, run 'pip install html5lib' or install html5lib
# print(soup.prettify())
# ```

# %% [markdown]
# # Getting text from the main website
# # After this we can also scrape text from embedded websites

# %%
# Since we have already established a connection with the website we do not need to do it again

# Create a BeautifulSoup object and parse the HTML content
soup = BeautifulSoup(r.content, 'html.parser')

# Extract all the text from the webpage
text = soup.get_text()

# Save the scraped data to a text file
with open('Main_website_data.txt', 'w') as f:
    f.write(text)

# %%
# Reading text from text file
with open('/content/Main_website_data.txt', 'r') as f:
    contents = f.read()
    print(contents)
# Out:
# Chhattisgarh Swami Vivekanand Technical University – CSVTU
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# FORMS / DOWNLOADS
# CSVTU NSS
# CSVTU STUDENT COUNCIL
# LOCATION
# PREVIOUS WEBSITE
# ENROLL. DEFICIENCIES
#
#
#
#
#
# Search for:
#
#
#
#
#
# Recent Posts
#
#
# Recruitment Notice For The Post of Principal, Professor, Asst. Professor, Asso. Professor & Lecturer  Under Statute-19 at Rungta Institute of Pharmaceutical Sciences, Bhilai
#
#
# Public Relations Officer
#
#
# AICTE Quality Improvement Scheme[AQIS] 2021-22 Financial Support
#
#
# M.Tech/M.Plan Admissions 2020 at University Teaching Department,CSVTU,Newai,Bhilai
#
#
# Important Notification-Suspicious Email Activities
#
#
# Recent CommentsArchives
#
# December 2021
# August 2021
# December 2020
# September 2020
# May 2020
# April 2020
# March 2020
#
# Categories
#
# Announcement
#
# Notice
#
# Uncategorized
#
#
# Meta
#
# Log in
# Entries feed
# Comments feed
# WordPress.org
#
#
#
#
#
#
#
#
#
#
# HOME
# THE UNIVERSITY
#
# About
# Hon’ble Vice Chancellor
# Hon’ble Pro Vice Chancellor
# University Values
# Academic Council
# Executive Council
# Finance Committee
# University Act
# Administration
# Ordinances & Amendments
# RTI
# Public Relations Officer
# Statutes
#
#
# AFFILIATED INSTITUTES
#
# Engineering
# Diploma
# Pharmacy
# B. Arch.
# MBA
# MCA
# M. Tech.
#
#
# ACADEMIC
#
# University Teaching Department
#
# Diploma
#
# Diploma in Mining Engineering
# Diploma in Industrial Safety & Fire Safety Engineering
#
#
# U.G
#
# B.Tech (Honours)
#
#
# P.G
#
# Structural Engineering
# Urban Planning
# Environmental and Water Resources Engineering
# Energy and Environmental Engineering
# Biomedical Engineering & Bioinformatics
# Microelectronics and VLSI
#
#
#
#
# Seniority List
# Academic Calendar
# Programs and Schemes
# Admissions
# Merit List
# Recruitment
#
#
# RESEARCH
#
# Ph.D. Information
# CSVTU  Journal
# Research & Development Promotional Schemes
# International Relationship
#
# Adjunct Professors
# MOUs
#
#
#
#
# NOTICES/TENDERS
#
# Notices
#
# Institutes Notices
# Students Notices
# Principal & Director Notices
# Faculties Notices
#
#
# Tenders
#
#
# TEQIP
#
# TEQIP-III
#
# About Us
#
#
# Program
#
# Equity Action Plan
# ‘MHRD’s Innovation Cell (MIC)
# Press Release
# Workshop/Seminar/STTP/Symposiums
# Twinning Programme
# Internship Program
#
#
# TEQIP-Notices & Reports
# Team Member
# Contact Person
#
#
# MEDIA
#
# Gallery
# Video Gallery
#
#
# RESULTS
#
# Results (Reg/Supply)
# Result (RT)
# Results (RV)
# Results (RRV)
#
#
# SPORTS
#
# Home Page
# Sports Committee
# Sports Notification
# Sports Activities
# Cultural / Other Activities
# Sports Photo Gallery
# Sports Fee
# Contact Us
#
#
# RECRUITMENT
# NEWSLETTER
# Contact Us
#
#
#
#
#
#
#
#
#
#
# "Arise! Awake! and stop not until the goal is reached."
#
#
#
#
#
#
#
# HOME
# THE UNIVERSITY
#
# About
# Hon’ble Vice Chancellor
# Hon’ble Pro Vice Chancellor
# University Values
# Academic Council
# Executive Council
# Finance Committee
# University Act
# Administration
# Ordinances & Amendments
# RTI
# Public Relations Officer
# Statutes
#
#
# AFFILIATED INSTITUTES
#
# Engineering
# Diploma
# Pharmacy
# B. Arch.
# MBA
# MCA
# M. Tech.
#
#
# ACADEMIC
#
# University Teaching Department
#
# Diploma
#
# Diploma in Mining Engineering
# Diploma in Industrial Safety & Fire Safety Engineering
#
#
# U.G
#
# B.Tech (Honours)
#
#
# P.G
#
# Structural Engineering
# Urban Planning
# Environmental and Water Resources Engineering
# Energy and Environmental Engineering
# Biomedical Engineering & Bioinformatics
# Microelectronics and VLSI
#
#
#
#
# Seniority List
# Academic Calendar
# Programs and Schemes
# Admissions
# Merit List
# Recruitment
#
#
# RESEARCH
#
# Ph.D. Information
# CSVTU  Journal
# Research & Development Promotional Schemes
# International Relationship
#
# Adjunct Professors
# MOUs
#
#
#
#
# NOTICES/TENDERS
#
# Notices
#
# Institutes Notices
# Students Notices
# Principal & Director Notices
# Faculties Notices
#
#
# Tenders
#
#
# TEQIP
#
# TEQIP-III
#
# About Us
#
#
# Program
#
# Equity Action Plan
# ‘MHRD’s Innovation Cell (MIC)
# Press Release
# Workshop/Seminar/STTP/Symposiums
# Twinning Programme
# Internship Program
#
#
# TEQIP-Notices & Reports
# Team Member
# Contact Person
#
#
# MEDIA
#
# Gallery
# Video Gallery
#
#
# RESULTS
#
# Results (Reg/Supply)
# Result (RT)
# Results (RV)
# Results (RRV)
#
#
# SPORTS
#
# Home Page
# Sports Committee
# Sports Notification
# Sports Activities
# Cultural / Other Activities
# Sports Photo Gallery
# Sports Fee
# Contact Us
#
#
# RECRUITMENT
# NEWSLETTER
# Contact Us
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Easy to customize
#
#
#
#
# Responsive, Professional & Modern Multi-purpose theme
#
#
#
#
#
#
#
#
#
#
#
#                 Recruitment Notice For The Post of Principal, Professor, Asst. Professor, Asso. Professor & Lecturer  Under Statute-19 at Rungta Institute of Pharmaceutical Sciences, Bhilai
#
#
#
#
# Read More
#
#
#
#
#
#
#
#
#
#
#
#                 Public Relations Officer
#
#
#             Name :    Mr. Kishor Kumar Bhardwaj Designation :    I/C Public Relations Officer Email :    pro@csvtu.ac.in Mobile No. :
#
# Read More
#
#
#
#
#
#
#
#
#
#
#
#                 AICTE Quality Improvement Scheme[AQIS] 2021-22 Financial Support
#
#
#             [supsystic-tables id=20] [supsystic-tables id=21] [supsystic-tables id=22]
#
# Read More
#
#
#
#
#
#
#
#
#
#
#
#                 M.Tech/M.Plan Admissions 2020 at University Teaching Department,CSVTU,Newai,Bhilai
#
#
#             Brochure [ M.Tech/M.Plan Admissions 2020] Admission Portal Link [pdf-embedder url="https://csvtu.ac.in/ew/wp-content/uploads/2020/09/FLYER.pdf"]
#
# Read More
#
#
#
#
#
#
#
#
#
#
#
#                 Important Notification-Suspicious Email Activities
#
#
#             Dear All It has been reported that there was an email received by the name of our Hon'ble Vice Chancellor Dr. M.K Verma on several email id's from the email id : "directormailhicey@gmail.com" stating "I need a help kindly email me back as soon as possible" It is to inform…
#
# Read More
#
#
#
#
#
#
#
#
#
#
#
#                 Disclaimer
#
#
#             This is to inform you all that university has not published or circulated any exam time table[For APR-May 2020] till date . It will be published only in the CSVTU website and will be sent to all the affiliated institutions. Please refrain from fake information.
#
# Read More
#
#
#
#
#
#
#
#
#
#
#
#                 Exam Help-Line Numbers During Lock-Down Period
#
#
#             Students can also call/email to their Institute's Helpline numbers/email id's mentioned in their Institute's website. [supsystic-tables id=18]
#
# Read More
#
#
#
#
#
#
#
#
#
#
#
#                 Notification Regarding Ph.D Course-Work Examination
#
#
#             It is hereby informed that the Ph D course work examination originally scheduled for April 3, 2020 is postponed till further notice in wake of lockdown imposed for stopping the spread of COVID-19.
#
# Read More
#
#
#
#
#
#
#
#
#
# 	     LatestNotification – RV / RT (MCA/B.Pharma/BTech (Honors)
#
# 	     LatestLast Spot Round admission on “First Come First Serve Basis” for B.Tech, M.Tech and PG Diploma Courses for session 2023-24
#
# 	     Latest2nd Spot Round Admission Merit List of UTD, CSVTU Bhilai in B.tech Course for session 2023-24
#
# 	     LatestInternal Hackathon for SIH 2023
#
# 	     LatestJoSAA/CSAB Merit list of University level spot admission at UTD CSVTU for session 2023-24
#
# 	     LatestSpot Round Admission for PG and PG Diploma Courses for session 2023-24
#
# 	     LatestNotice of Candidates in waiting list against the advertisement No. CSVTU/Advt./2023/128 Dated: 06/06/2023
#
# 	     LatestNotice of Candidates in waiting list against the advertisement No. CSVTU/Advt./2023/129 Dated: 06/06/2023
#
# 	     LatestProvisional selection list of 2nd Phase Admission for PG and PG Diploma Courses for session 2023-24
#
# 	     LatestNotice for Institute level Spot Admission in B.Tech(Hons.)-Session 2023-24 for JoSAA/CSAB candidates
#
# 	     Latest2nd Phase Admission for PG and PG Diploma Courses for session 2023-24
#
# 	     LatestCSVTU Bhilai will remain open on Sunday (20th August 2023) for admission process
#
# 	     LatestProvisional selection list of PG and PG Diploma Courses for session 2023-24
#
# 	     LatestNotice of Candidates appointed against advertisement.
#
# 	     LatestPG (M. Tech / M.Plan ) and PG Diploma Admission Advertisement & Notification for session 2023-24
#
# 	     LatestNotification for written test with reference to CSVTU/ Advt./2023/129
#
# 	     LatestAdvertisement for the Post of Assistant Professor,Professor & Associate Professor CSVTU, Bhilai ( C.G.)
#
# 	     LatestAdvertisement for the Post of Assistant Professor -Pharmacy (PT) CSVTU, Bhilai ( C.G.)
#
# 	     LatestTwo Days National Seminar on National Education Policy for Technical Education Excellence & Scientific Terminology in Indian Languages (23rd-24th June 2023)
#
# 	     LatestAdvertisement for the Engagement of Junior Consultants (UTD)
# 	     LatestAdvertisement for the Engagement of Project Manager and Deputy Project Manager for Skill Development Program
# 	     LatestAdvertisement for the Engagement of Junior Consultant (University)
#
# 	     LatestCGPA/CPI को Percentage में बदलने के दस्तावेज के संबंध में
#
# 	     LatestRFP for “Empanelment of Channel-Partner for promotion of rural and agro-enterprises through e-Commerce and Market Research (e-CMR) Platform of CSVTU-FORTE”
#
# 	     LatestWorkshop On 3D Character Design for Gaming and Animation Industry 13th May 2023 at UTD, CSVTU, Bhilai
#
# 	     LatestNotice for Fee Refund (Alloted through CSAB 2022-23)[IMPORTANT NOTE: Students who have not filled out the Google form for Fee Refund may fill it on or before March 25th, 2023 ]
#
# 	     LatestCorrigendum regarding walk in interview scheduled on 16.02.2023
#
# 	     LatestVacant seats details of M.Tech Sponsorship Quota (SQ) as on 19/01/2023 at 05:30 PM.
#
# 		     LatestVacant seats details of M.Tech Sponsorship Quota (SQ) as on 18/01/2023 at 05:30 PM.
#
# 	     LatestNotification for M.Tech. Admission for Sponsored Candidates of Session 2022-23
#
# 	     LatestNotice for Rescheduling of Interview Dated 21/12/2022
#
# 	     LatestVacant Seat Details 14.12.22
#
# 	     LatestVacant Seats Details for B.Tech. Course as on 13.12.22
#
# 	     LatestFinal Spot admission (Based on physical reporting) against JoSAA/CSAB vacant seats at UTD, CSVTU Bhilai for Session 2022-23
#
# 	     LatestVacant Seats Details for Spot admission as on 09.12.22 (Based on physical reporting) at UTD, CSVTU Bhilai for Session 2022-23
#
# 	     LatestSpot admission (Based on physical reporting) against JoSAA/CSAB vacant seats at UTD, CSVTU Bhilai for Session 2022-23
#
# 	     Latest2nd Cleared Waiting List of University level spot admission against JoSAA/CSAB vacant seats at UTD, CSVTU Bhilai for Session 2022-23
#
# 	     Latest1st Cleared Waiting List of University level spot admission against JoSAA/CSAB vacant seats at UTD, CSVTU Bhilai for Session 2022-23
#
# 	     LatestMerit List of University level spot admission against JoSAA/CSAB vacant seats at UTD, CSVTU Bhilai for Session 2022-23.
#
# 	     LatestExtension Notice of Last Date of Submission of the application forms for University Level Spot Admission 2022-23.
# 	     LatestUniversity level spot admission against JoSAA/CSAB vacant seats at UTD, CSVTU Bhilai for Session 2022-23
#
# 	     LatestAdmission Notice for B.Tech. (Honours) through JoSAA/CSAB 2022-23
# 	     Latest1st Phase Provisional selection list of M.Plan Course for session 2022-23
#
# 	     LatestNotice:-Regarding Spot Counselling Admission Detail
#
# 		     LatestNotification: Admission in M.Plan Course for  Session 2022-23
#
# 	     LatestNotification: Admission in Ph.D. Programme for 2022-23 Under AICTE Doctoral Fellowship(ADF) Scheme
#
# 	     Latest Highlights of Inaugural ceremony of  Vishveshwarayya Bhawan at  CSVTU Bhilai by Hon. Chief Minister Sir.
#
# 	     LatestVideo of Inauguration ceremony of New UTD Building at CSVTU by Hon. Chief Minister Sir.
#
#
# 	     LatestVideo of MoU between CSVTU and NucleusTech software company.
#
#
# 	     LatestRegarding Fee for Student admitted in Session 2021-2022
#
# 	     LatestClick here for FEE PAYMENT for students admitted in 2021-22
# 	     LatestSchedule of walk in interview for the post of Temporary Faculty
#
# 	     LatestAdvertisement for Walk-in-Interview for the Post of Temporary Faculty in UTD, CSVTU Bhilai
#
# 	     LatestNotice: Advertisement of Engagement for Sr. Consultant & Jr. Consultant
#
# 	     Latestमहामहिम राज्यपाल सुश्री अनुसुईया उइके जी का  छत्तीसगढ़ स्वामी विवेकानंद तकनीकी विश्वविद्यालय के छात्रों को संदेश  9 जनवरी 2022
# 	     Latestयुवा दिवस के अवसर पर माननीय कुलपति महोदय का छात्रों को संदेश
#
# 		     LatestNotice: Regarding Opening of Link of Enrollment Form-2021-22
#
# 	     LatestNotice: Regarding Last Round Spot Admission Merit List at UTD,CSVTU,Bhilai Session 2021-22
#
# 	     LatestNotice for Last Round to Take Admission Against Vacant Seat at University Teaching Department(UTD), CSVTU Bhilai For Session 2021-22
#
# 	     LatestNotice: Regarding Merit List of University Level Spot Admission against vacant seat at University Teaching Department (UTD), CSVTU Bhilai CG for session 2021-22
#
#
#
# 			     LatestAdvertisement for Walk-in-Interview for the Post of Temporary Faculty in UTD, CSVTU Bhilai
#
# 	     LatestAdvertisement for Engagement of Consultant(Library) CSVTU Bhilai
#
#
#      LatestNotice Regarding Appearing in four Subjects for Aggregate Clearance
#
#
#      LatestAmendment in Ordinance No.10 Doctor of Philosophy [w.e.f 08/12/2020]
#
#      LATESTNotice -Regarding Exam Form Filling Date Extension [Revised]
#
#      LATESTऑनलाइन परीक्षा के संबंध में छात्रों को दिशानिर्देश [संशोधित]
#
#      NEWAICTE Quality Improvement Scheme[AQIS] 2021-22 Financial Support
#
#
#
#
#
# Admission 2022-23
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# INFORMATION FOR JOURNAL READERS
#
# We encourage readers to sign up for the publishing notification service for this journal. Use the Register link at the top of the home page for the journal. This registration will result in the reader receiving the Table of Contents by email for each new issue of the journal.
# Read more
#
# ABOUT THE UNIVERSITY
# Chhattisgarh Swami Vivekanand Technical University (CSVTU) was established by an act (No. 25 of 2004) of legislature passed by the Chhattisgarh State Govt. Assembly vide notification no. 639/21-A/Praroopan/04 dt 21st January 2005.
# Read more
#
#
# SWAMI VIVEKANAND YUVA KAUSHAL SETU
#
#  SVYKS an
#
# 						initiative of CSVTU, launched for Recognition of Prior Learning (RPL).RPL focuses on enhancing the career/employability opportunities of an individual as well as provide alternative routes to higher education. It also envisages providing opportunities for reducing inequalities based on privileging certain forms of knowledge over others.
# Read more
#
#
#
#
#
#
#
# "The greatest sin is to think yourself weak"
#
#
#
#
#    DigiVarsity
#    E-Library
#
#
#
#
#
#
#
# NOTICES & Announcements
#
#
#
# Notification – RV / RT (MCA/B.Pharma/BTech (Honors)
#
# 											October 6, 2023
#
#
# Revised Final List of Rejected Candidate
#
# 											October 3, 2023
#
#
# Revised Final List of Exempted from Written Test
#
# 											October 3, 2023
#
#
# Revised Final List of Written Test
#
# 											October 3, 2023
#
#
# Notice – Ph.D.Viva-Voce Examination-Ms. Suchitra Pandey (Open-Defence)
#
# 											October 3, 2023
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# GET A NO-RISK, FREE CONSULTATION TODAY
#
#
#
#                         CONTACT US
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     © 2015 Your company name
#
#
#
#                         Design by SmartCat
#
#
#
#
#
#
#
#
#
#
# Newai, P.O.-Newai, District- Durg (Chhattisgarh), PIN-491107
#
#  INDIA
# Tel.: +91-788-2200062
#
# Exam Helpline No. +91-788-2445035, Fax: +91-788-2445020
#
#
#
# Email: enquiry@csvtu.ac.in
#
#
# About University
#
# Genesis of University
# University Values
# University Act
# Contact Details
#
#
#
# Students
#
# Results (Reg/Supply)
# Results (RT) Results (RV)
# Results (RRV)
# Syllabus
#
#
# Grievance Cell
# Download Form
# Academic Calendar
# Online Fee Payment
# Examination Time Table
#
#
#
# Important Links
#
# Raj Bhavan Chhattisgarh
# UGC
# AICTE
# CG DTE
# CG Government
# NPTEL
# SWAYAM
# MHRD
#
#
# DST
# CSIR
# AIU
# NISCAIR
# NAD
# NDL
# SVYKS
#
#
#
#
#
#
#
#
#
# 			.:DISCLAIMER:.
#
# 			Results published in the university website shall serve the purpose of only first hand information to the students. However the same indicated in Tabulation Sheet with university seal & signature by competent authority should be considered genuine for all purpose.
#
# ©All Right Reserved. Chhattisgarh Swami Vivekanand Technical University, Chhattisgarh, INDIA

# %% [markdown]
# ## Reading text from embedded websites

# %%
# First we will iterate through all the links and then read text from there

print("Embedded Links are:\n")
# Open the file for reading
with open('/content/Embedded_links_csvtu.txt', 'r') as file:

    # Read and process each line
    for line in file:
        # Print the line (you can replace this with any action you want)
        print(line.strip())  # .strip() removes newline characters if needed
# Out:
# Embedded Links are:
#
# https://csvtu.ac.in/ew/downloads
# http://csvtu.ac.in/NSS_CSVTU/
# https://csvtu.ac.in/ew/csvtu-student-council/
# https://csvtu.ac.in/ew/contact-us/
# http://www.csvtu.ac.in/prev/
# https://csvtu.ac.in/ew/enrollment-deficiencies/
# https://csvtu.ac.in/ew/recruitment-notice-for-the-post-of-principal-professor-asst-professor-asso-professor-lecturer-under-statute-19-at-rungta-institute-of-pharmaceutical-sciences-bhilai/
# https://csvtu.ac.in/ew/public-relations-officer/
# https://csvtu.ac.in/ew/aicte-quality-improvement-schemeaqis-2021-22-financial-support/
# https://csvtu.ac.in/ew/m-techm-plan-admissions-2020-at-university-teaching-departmentcsvtunewaibhilai/
# https://csvtu.ac.in/ew/important-notification/
# https://csvtu.ac.in/ew/2021/12/
# https://csvtu.ac.in/ew/2021/08/
# https://csvtu.ac.in/ew/2020/12/
# https://csvtu.ac.in/ew/2020/09/
# https://csvtu.ac.in/ew/2020/05/
# https://csvtu.ac.in/ew/2020/04/
# https://csvtu.ac.in/ew/2020/03/
# https://csvtu.ac.in/ew/category/announcement/
# https://csvtu.ac.in/ew/category/notice/
# https://csvtu.ac.in/ew/category/uncategorized/
# https://csvtu.ac.in/ew/wp-login.php
# https://csvtu.ac.in/ew/feed/
# https://csvtu.ac.in/ew/comments/feed/
# https://wordpress.org/
# http://csvtu.ac.in/ew/
# #
# https://csvtu.ac.in/ew/the-university/overview/
# https://csvtu.ac.in/ew/the-university/hvc-message/
# https://csvtu.ac.in/ew/the-university/pro-vice-chancellor/
# https://csvtu.ac.in/ew/the-university/university-values/
# https://csvtu.ac.in/ew/the-university/academic-council/
# https://csvtu.ac.in/ew/the-university/executive-council/
# https://csvtu.ac.in/ew/the-university/finance-council/
# http://csvtu.ac.in/ew/university-act-2/
# https://csvtu.ac.in/ew/the-university/university-administration/
# https://csvtu.ac.in/ew/the-university/ordinances/
# https://csvtu.ac.in/ew/rti/
# https://csvtu.ac.in/ew/public-relations-officer
# https://csvtu.ac.in/ew/statutes/
# #
# https://csvtu.ac.in/ew/the-institute/engineering/
# https://csvtu.ac.in/ew/the-institute/diploma/
# https://csvtu.ac.in/ew/the-institute/pharmacy/
# https://csvtu.ac.in/ew/the-institute/b-arch/
# https://csvtu.ac.in/ew/the-institute/mba/
# https://csvtu.ac.in/ew/the-institute/mca/
# https://csvtu.ac.in/ew/the-institute/me-m-tech/
# #
# https://csvtu.ac.in/ew/about-the-university-teaching-department/
# #
# https://csvtu.ac.in/ew/university-teaching-department-diploma-in-mining-engineering/
# https://csvtu.ac.in/ew/university-teaching-department-industrial-safety-fire-safety-engineering/
# https://csvtu.ac.in/ew/about-the-university-teaching-department/
# https://csvtu.ac.in/ew/university-teaching-department-2/
# https://csvtu.ac.in/ew/about-the-university-teaching-department/
# https://csvtu.ac.in/ew/department-of-structural-engineering/
# https://csvtu.ac.in/ew/department-of-urban-planning/
# https://csvtu.ac.in/ew/department-of-environmental-and-water-resources-engineering/
# https://csvtu.ac.in/ew/department-of-energy-and-environmental-engineering/
# https://csvtu.ac.in/ew/department-of-biomedical-engineering-bioinformatics/
# https://csvtu.ac.in/ew/department-of-microelectronics-and-vlsi/
# https://csvtu.ac.in/ew/seniority-list/
# https://csvtu.ac.in/ew/academic-calendar/
# https://csvtu.ac.in/ew/programs-and-schemes/
# https://csvtu.ac.in/ew/admissions/
# https://csvtu.ac.in/ew/merit-list/
# https://csvtu.ac.in/ew/recruitment-2/
# #
# https://csvtu.ac.in/ew/research/phd-information/
# https://csvtujournal.in/
# https://csvtu.ac.in/ew/research-development-promotional-schemes/
# #
# https://csvtu.ac.in/ew/international-relations/
# http://csvtu.ac.in/ew/memorandum-of-understanding-mous/
# https://csvtu.ac.in/ew/notices/
# https://csvtu.ac.in/ew/notices/
# https://csvtu.ac.in/ew/notices/institutes-notices/
# #
# https://csvtu.ac.in/ew/notices/principal-and-director-notices/
# #
# https://csvtu.ac.in/ew/tenders/
# #
# #
# http://csvtu.ac.in/ew/about-as/
# #
# http://csvtu.ac.in/ew/updates/notices/teqip-format/_EAP%202020-21%20final.pdf
# https://www.mic.gov.in/iic.html
# http://csvtu.ac.in/ew/press-release/
# http://csvtu.ac.in/ew/program-list/
# https://csvtu.ac.in/ew/twinning-programme/
# https://csvtu.ac.in/ew/teqip-notices/internship-program/
# https://csvtu.ac.in/ew/teqip-notices/
# http://csvtu.ac.in/ew/teams/
# http://csvtu.ac.in/ew/contact-p/
# #
# https://csvtu.ac.in/ew/media/gallery/
# https://csvtu.ac.in/ew/video-gallery/
# #
# https://csvtu.ac.in/ew/result-reg-supply/
# https://csvtu.ac.in/ew/result-rt/
# https://csvtu.ac.in/ew/result-rv/
# https://csvtu.ac.in/ew/results-rrv/
# #
# https://csvtu.ac.in/ew/home-page/
# https://csvtu.ac.in/ew/sports-committee/
# https://csvtu.ac.in/ew/sports-notification/
# https://csvtu.ac.in/ew/sports-activities/
# https://csvtu.ac.in/ew/cultural-other-activities/
# https://csvtu.ac.in/ew/sports-photo-gallery/
# https://csvtu.ac.in/ew/sports-fee/
# https://csvtu.ac.in/ew/contact-us-2/
# https://csvtu.ac.in/ew/recruitment-2/
# https://csvtu.ac.in/ew/newsletter/
# http://csvtu.ac.in/ew/contact-us/
# https://csvtu.ac.in/ew/
# http://csvtu.ac.in/ew/
# #
# https://csvtu.ac.in/ew/the-university/overview/
# https://csvtu.ac.in/ew/the-university/hvc-message/
# https://csvtu.ac.in/ew/the-university/pro-vice-chancellor/
#
# https://csvtu.ac.in/ew/news/notice-for-last-round-to-take-admission-against-vacant-seat-at-university-teaching-departmentutd-csvtu-bhilai-for-session-2021-22/
#
# https://csvtu.ac.in/ew/news/notice-regarding-merit-list-of-university-level-spot-admission-against-vacant-seat-at-university-teaching-department-utd-csvtu-bhilai-cg-for-session-2021-22/
#
# https://csvtu.ac.in/ew/news/advertisement-for-walk-in-interview-for-the-post-of-temporary-faculty-in-utd-csvtu-bhilai/
#
# https://csvtu.ac.in/ew/news/advertisement-for-engagement-of-consultantlibrary-csvtu-bhilai/
#
# https://csvtu.ac.in/ew/news/notice-regarding-appearing-in-four-subjects-for-aggregate-clearance/
#
# https://csvtu.ac.in/ew/research/phd-information/
# https://csvtu.ac.in/ew/news/notice-regarding-exam-form-filling-date-extension-revised/
# https://csvtu.ac.in/ew/news/%e0%a4%91%e0%a4%a8%e0%a4%b2%e0%a4%be%e0%a4%87%e0%a4%a8-%e0%a4%aa%e0%a4%b0%e0%a5%80%e0%a4%95%e0%a5%8d%e0%a4%b7%e0%a4%be-%e0%a4%95%e0%a5%87-%e0%a4%b8%e0%a4%82%e0%a4%ac%e0%a4%82%e0%a4%a7-%e0%a4%ae-2/
# https://csvtu.ac.in/ew/aicte-quality-improvement-schemeaqis-2021-22-financial-support/
# https://csvtu.ac.in/ew/university-teaching-departmentprograms-and-schemes/
# https://csvtu.ac.in/ew/results-rtrvrrv/
# https://csvtu.ac.in/ew/examination-time-table/
# https://csvtu.ac.in/ew/programs-and-schemes/
# https://csvtu.ac.in/ew/academic-calendar/
# https://csvtu.ac.in/ew/enrollment-form-2016/
# https://csvtu.ac.in/ew/examination-form-2016/
# https://csvtu.ac.in/ew/notices/
# https://csvtu.ac.in/ew/centre-for-skill-development-and-informal-education-csdie/
# https://csvtu.ac.in/ew/university-teaching-department/
# https://csvtu.ac.in/ew/centralized-placement-cell-cpc/
# https://csvtu.ac.in/ew/grievance-cell/
# https://csvtujournal.in/
# https://csvtu.ac.in/ew/overview
# https://svyks.in/index.html
# https://csvtu.ac.in/ew/teqip-downloads/
# http://csvtu.digivarsity.online/
# https://csvtu.ac.in/ew/?page_id=17657&preview=true
# https://csvtu.ac.in/ew/news/final-seniority-list-2023/
# https://csvtu.ac.in/ew/news/notification-rv-rt-mca-b-pharma-btech-honors/
# https://csvtu.ac.in/ew/news/revised-final-list-of-rejected-candidate/
# https://csvtu.ac.in/ew/news/revised-final-list-of-exempted-from-written-test/
# https://csvtu.ac.in/ew/news/revised-final-list-of-written-test/
# #
# http://smartcatdesign.net/
# https://csvtu.ac.in/ew/overview
# https://csvtu.ac.in/ew/university-values
# https://csvtu.ac.in/ew/download/University act Hindi_English 2004.pdf
# https://csvtu.ac.in/ew/contact-us
# https://csvtu.ac.in/ew/result-reg-supply/
# https://csvtu.ac.in/ew/result-rt/
# https://csvtu.ac.in/ew/result-rv/
# https://csvtu.ac.in/ew/results-rrv/
# https://csvtu.ac.in/ew/programs-and-schemes/
# https://csvtu.ac.in/ew/grievance-cell/
# https://csvtu.ac.in/ew/downloads/
# https://csvtu.ac.in/ew/academic-calendar/
# https://csvtu.ac.in/ew/online-fee-payment/
# https://csvtu.ac.in/ew/examination-time-table/
# https://rajbhavancg.gov.in/
# http://www.ugc.ac.in/
# http://www.aicte-india.org/
# http://www.cgdteraipur.ac.in/
# http://www.cgstate.gov.in
# http://onlinecourses-archive.nptel.ac.in
# https://swayam.gov.in/explorer
# https://mhrd.gov.in/ict-initiatives
# http://www.dst.gov.in/
# http://www.csir.res.in/
# http://www.aiu.ac.in/
# http://www.niscair.res.in/
# http://nad.gov.in
# https://ndl.iitkgp.ac.in/
# https://www.svyks.in

# %%
# Open the file for reading
# Adding links to list
lst = []
with open('/content/Embedded_links_csvtu.txt', 'r') as file:
    # Read and process each line
    for line in file:
        # Appending to list
        lst.append(line.strip())  # .strip() removes newline characters if needed

# %% [markdown]
# ## Removing '#' and '' from links and unreachable links from list

# %%
# We need to remove # from list
new_lst = list(filter(lambda x: x != '#' and x != '' and x != '/csvtubhilaif/add' and x != 'act Hindi_English 2004.pdf', lst))

# Print list
print("List is:")
print(new_lst)
# Out:
# List is:
# ['https://csvtu.ac.in/ew/downloads', 'http://csvtu.ac.in/NSS_CSVTU/', 'https://csvtu.ac.in/ew/csvtu-student-council/', 'https://csvtu.ac.in/ew/contact-us/', 'http://www.csvtu.ac.in/prev/', 'https://csvtu.ac.in/ew/enrollment-deficiencies/', 'https://csvtu.ac.in/ew/recruitment-notice-for-the-post-of-principal-professor-asst-professor-asso-professor-lecturer-under-statute-19-at-rungta-institute-of-pharmaceutical-sciences-bhilai/', 'https://csvtu.ac.in/ew/public-relations-officer/', 'https://csvtu.ac.in/ew/aicte-quality-improvement-schemeaqis-2021-22-financial-support/', 'https://csvtu.ac.in/ew/m-techm-plan-admissions-2020-at-university-teaching-departmentcsvtunewaibhilai/', 'https://csvtu.ac.in/ew/important-notification/', 'https://csvtu.ac.in/ew/2021/12/', 'https://csvtu.ac.in/ew/2021/08/', 'https://csvtu.ac.in/ew/2020/12/', 'https://csvtu.ac.in/ew/2020/09/', 'https://csvtu.ac.in/ew/2020/05/', 'https://csvtu.ac.in/ew/2020/04/', 'https://csvtu.ac.in/ew/2020/03/', 'https://csvtu.ac.in/ew/category/announcement/', 'https://csvtu.ac.in/ew/category/notice/', 'https://csvtu.ac.in/ew/category/uncategorized/', 'https://csvtu.ac.in/ew/wp-login.php', 'https://csvtu.ac.in/ew/feed/', 'https://csvtu.ac.in/ew/comments/feed/', 'https://wordpress.org/', 'http://csvtu.ac.in/ew/', 'https://csvtu.ac.in/ew/the-university/overview/', 'https://csvtu.ac.in/ew/the-university/hvc-message/', 'https://csvtu.ac.in/ew/the-university/pro-vice-chancellor/', 'https://csvtu.ac.in/ew/the-university/university-values/', 'https://csvtu.ac.in/ew/the-university/academic-council/', 'https://csvtu.ac.in/ew/the-university/executive-council/', 'https://csvtu.ac.in/ew/the-university/finance-council/', 'http://csvtu.ac.in/ew/university-act-2/', 'https://csvtu.ac.in/ew/the-university/university-administration/', 'https://csvtu.ac.in/ew/the-university/ordinances/', 'https://csvtu.ac.in/ew/rti/', 'https://csvtu.ac.in/ew/public-relations-officer', 'https://csvtu.ac.in/ew/statutes/', 'https://csvtu.ac.in/ew/the-institute/engineering/', 'https://csvtu.ac.in/ew/the-institute/diploma/', 'https://csvtu.ac.in/ew/the-institute/pharmacy/', 'https://csvtu.ac.in/ew/the-institute/b-arch/', 'https://csvtu.ac.in/ew/the-institute/mba/', 'https://csvtu.ac.in/ew/the-institute/mca/', 'https://csvtu.ac.in/ew/the-institute/me-m-tech/', 'https://csvtu.ac.in/ew/about-the-university-teaching-department/', 'https://csvtu.ac.in/ew/university-teaching-department-diploma-in-mining-engineering/', 'https://csvtu.ac.in/ew/university-teaching-department-industrial-safety-fire-safety-engineering/', 'https://csvtu.ac.in/ew/about-the-university-teaching-department/', 'https://csvtu.ac.in/ew/university-teaching-department-2/', 'https://csvtu.ac.in/ew/about-the-university-teaching-department/', 'https://csvtu.ac.in/ew/department-of-structural-engineering/', 'https://csvtu.ac.in/ew/department-of-urban-planning/', 'https://csvtu.ac.in/ew/department-of-environmental-and-water-resources-engineering/', 'https://csvtu.ac.in/ew/department-of-energy-and-environmental-engineering/', 'https://csvtu.ac.in/ew/department-of-biomedical-engineering-bioinformatics/', 'https://csvtu.ac.in/ew/department-of-microelectronics-and-vlsi/', 'https://csvtu.ac.in/ew/seniority-list/', 'https://csvtu.ac.in/ew/academic-calendar/', 'https://csvtu.ac.in/ew/programs-and-schemes/', 'https://csvtu.ac.in/ew/admissions/', 'https://csvtu.ac.in/ew/merit-list/', 'https://csvtu.ac.in/ew/recruitment-2/', 'https://csvtu.ac.in/ew/research/phd-information/', 'https://csvtujournal.in/', 'https://csvtu.ac.in/ew/research-development-promotional-schemes/', 'https://csvtu.ac.in/ew/international-relations/', 'http://csvtu.ac.in/ew/memorandum-of-understanding-mous/', 'https://csvtu.ac.in/ew/notices/', 'https://csvtu.ac.in/ew/notices/', 'https://csvtu.ac.in/ew/notices/institutes-notices/', 'https://csvtu.ac.in/ew/notices/principal-and-director-notices/', 'https://csvtu.ac.in/ew/tenders/', 'http://csvtu.ac.in/ew/about-as/', 'http://csvtu.ac.in/ew/updates/notices/ ...

# %% [markdown]
# ## Since certain embedded links do not allow access we have to use exception handling to continue the scraping without interruption.

# %%
# Loop through the list of URLs and scrape their content
for url in new_lst:
    try:
        # Send an HTTP request to the URL of the webpage we want to access
        r = requests.get(url)

        # Check for any HTTP errors
        r.raise_for_status()

        # Create a BeautifulSoup object and parse the HTML content
        soup = BeautifulSoup(r.content, 'lxml')

        # Extract all the text from the webpage
        text = soup.get_text()

        # Save the scraped data to a text file
        with open('Embedded_links_data_2.txt', 'a') as f:
            f.write(text)

    except requests.exceptions.ConnectTimeout as e:
        print(f"Connection to {url} timed out. Check your internet connection.")
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
# Out:
# /usr/local/lib/python3.10/dist-packages/bs4/builder/__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# An error occurred: 403 Client Error: Forbidden for url: https://forms.eduqfix.com/csvtubhilaif/add
# An error occurred: 403 Client Error: Forbidden for url: https://forms.eduqfix.com/csvtubhilaif/add
# Connection to https://rajbhavancg.gov.in/ timed out. Check your internet connection.
# An error occurred: HTTPConnectionPool(host='www.cgdteraipur.ac.in', port=80): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x7c65fe7b2f50>: Failed to resolve 'www.cgdteraipur.ac.in' ([Errno -2] Name or service not known)"))
# An error occurred: HTTPSConnectionPool(host='www.csir.res.in', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# An error occurred: 406 Client Error: Not Acceptable for url: http://www.aiu.ac.in/
# Connection to http://www.niscair.res.in/ timed out. Check your internet connection.

# %%
# Combining text files
# Define the names of the two input text files
file1_name = '/content/Main_website_data.txt'
file2_name = '/content/Embedded_links_data_2.txt'

# Define the name of the output file where you want to concatenate the contents
output_file_name = 'CSVTU_scraped_data.txt'

# Open the first input file for reading
with open(file1_name, 'r') as file1:
    content1 = file1.read()

# Open the second input file for reading
with open(file2_name, 'r') as file2:
    content2 = file2.read()

# Combine the contents of both files
combined_content = content1 + content2

# Open the output file for writing
with open(output_file_name, 'w') as output_file:
    # Write the combined content to the output file
    output_file.write(combined_content)

print(f"Concatenated content has been saved to {output_file_name}")
# Out:
# Concatenated content has been saved to CSVTU_scraped_data.txt

# %% [markdown]
# ## We have only done Web Scraping from main website and its embedded links but those embedded links may also have other links which may have useful data.So we are also extracting data from those websites which are embedded within the embedded links of the main website.

# %%
def web_Scraping_Text(url, visited_link, success_link):

  if url not in visited_link and 'csvtu.ac.in' in url:

    try:

      # Requesting website access for main website
      r = requests.get(url)

      # Since we have already established a connection with the website we do not need to do it again

      # Create a BeautifulSoup object and parse the HTML content
      soup = BeautifulSoup(r.content, 'lxml')

      visited_link.append(url)
      success_link.append(url)

      # Extract all the text from the webpage
      text = soup.get_text()

      # Find all the links on the webpage
      links = soup.find_all('a')

      # Save the scraped data to a text file
      with open('Complete_website_data.txt', 'a') as f:
          f.write(text)

      for link in links:

        # Creating an object and storing links
        href = link.get('href')

        # To ensure we are scraping the link
        if href is not None and 'csvtu.ac.in' in href and href not in visited_link:

          web_Scraping_Text(href, visited_link, success_link)


    except requests.exceptions.ConnectTimeout as e:

          # Appending link to visited_link as we have already visited it
          visited_link.append(url)
          print(f"Connection to {link} timed out. Check your internet connection.")

    except requests.exceptions.RequestException as e:

          visited_link.append(url)
          print(f"An error occurred: {e}")

web_Scraping_Text("https://csvtu.ac.in/ew/", [], [])

# %% [markdown]
# ## We need to install PyPDF2 everytime we run this code.

# %%
# Installing Library to Read and Extract Text from PDF
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 2.6 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1

# %% [markdown]
# ## Defining a Recursive Function for Web Scraping all the embedded Website Text and Text from Embedded PDF Files.

# %%
# Importing Required Libraries
import requests
from bs4 import BeautifulSoup
import PyPDF2

# Declaring visited_link and pdf links as global variables so that all functions can access it
pdf_links, visited_links, success_links = [],[],[]

# Extracting text from pdf
def extract_text_from_pdf(url):

    # Making Global Variables so that we can use throughout the function
    global pdf_links, visited_links, success_links

    try:
        if url not in visited_links:
            response = requests.get(url, stream=True)

            # Check if the content-type is a PDF
            if 'application/pdf' in response.headers['content-type']:
                with open("temp_pdf.pdf", 'wb') as temp_pdf:
                    temp_pdf.write(response.content)

                text = ""

                with open("temp_pdf.pdf", 'rb') as pdf_file:
                    pdf_reader = PyPDF2.PdfFileReader(pdf_file)

                    for page_num in range(pdf_reader.numPages):
                        page = pdf_reader.getPage(page_num)
                        text += page.extractText()

                save_to_file(text)
                visited_links.append(url)
                pdf_links.append(url)

    except:
        visited_links.append(url)

def save_to_file(text):
    with open('Complete_website_data.txt', 'a', encoding = 'utf-8') as f:
        f.write(text)

def web_scraping_text(url):

    global pdf_links, visited_links, success_links

    if url not in visited_links and 'csvtu.ac.in' in url:
        try:
            # Requesting website access for the main website
            r = requests.get(url)

            # Create a BeautifulSoup object and parse the HTML content
            soup = BeautifulSoup(r.content, 'lxml')

            # Extract all the text from the webpage
            text = soup.get_text()

            if text is not None and text != '':
              save_to_file(text)
              success_links.append(url)

            # Find all the links on the webpage
            links = soup.find_all('a')

            visited_links.append(url)

            for link in links:
                # Creating an object and storing links
                href = link.get('href')

                # To ensure we are scraping the link which contains data from csvtu only
                if href is not None and 'csvtu.ac.in' in href and href not in visited_links:
                  # Check if the link points to a PDF
                    if href.lower().endswith('.pdf'):
                        extract_text_from_pdf(href)
                    else:
                        web_scraping_text(href)

        except requests.exceptions.ConnectTimeout as e:
            # Appending link to visited_links as we have already visited it
            visited_links.append(url)
            print(f"Connection to {url} timed out. Check your internet connection.")

        except requests.exceptions.RequestException as e:
            visited_links.append(url)
            print(f"An error occurred: {e}")

# Calling function
web_scraping_text("https://csvtu.ac.in/ew/")
# Out:
# /usr/local/lib/python3.10/dist-packages/bs4/builder/__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-f7b77648c70a> in <cell line: 87>()
#      85
#      86 # Calling function
# ---> 87 web_scraping_text("https://csvtu.ac.in/ew/")
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      73                         extract_text_from_pdf(url)
#      74                     else:
# ---> 75                         web_scraping_text(href)
#      76
#      77         except requests.exceptions.ConnectTimeout as e:
#
# <ipython-input-4-f7b77648c70a> in web_scraping_text(url)
#      51
#      52             # Create a BeautifulSoup object and parse the HTML content
# ---> 53             soup = BeautifulSoup(r.content, 'lxml')
#      54
#      55             # Extract all the text from the webpage
#
# /usr/local/lib/python3.10/dist-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     324         rejections = []
#     325         success = False
# --> 326         for (self.markup, self.original_encoding, self.declared_html_encoding,
#     327          self.contains_replacement_characters) in (
#     328              self.builder.prepare_markup(
#
# /usr/local/lib/python3.10/dist-packages/bs4/builder/_lxml.py in prepare_markup(self, markup, user_specified_encoding, exclude_encodings, document_declared_encoding)
#     214             exclude_encodings=exclude_encodings
#     215         )
# --> 216         for encoding in detector.encodings:
#     217             yield (detector.markup, encoding, document_declared_encoding, False)
#     218
#
# /usr/local/lib/python3.10/dist-packages/bs4/dammit.py in encodings(self)
#     440         # encoding.
#     441         if self.chardet_encoding is None:
# --> 442             self.chardet_encoding = chardet_dammit(self.markup)
#     443         if self._usable(self.chardet_encoding, tried):
#     444             yield self.chardet_encoding
#
# /usr/local/lib/python3.10/dist-packages/bs4/dammit.py in chardet_dammit(s)
#      44         if isinstance(s, str):
#      45             return None
# ---> 46         return chardet_module.detect(s)['encoding']
#      47 else:
#      48     def chardet_dammit(s):
#
# /usr/local/lib/python3.10/dist-packages/chardet/__init__.py in detect(byte_str, should_rename_legacy)
#      47         byte_str = bytearray(byte_str)
#      48     detector = UniversalDetector(should_rename_legacy=should_rename_legacy)
# ---> 49     detector.feed(byte_str)
#      50     return detector.close()
#      51
#
# /usr/local/lib/python3.10/dist-packages/chardet/universaldetector.py in feed(self, byte_str)
#     272                 self._charset_probers.append(MacRomanProber())
#     273             for prober in self._charset_probers:
# --> 274                 if prober.feed(byte_str) == ProbingState.FOUND_IT:
#     275                     self.result = {
#     276                         "encoding": prober.charset_name,
#
# /usr/local/lib/python3.10/dist-packages/chardet/charsetgroupprober.py in feed(self, byte_str)
#      68             if not prober.active:
#      69                 continue
# ---> 70             state = prober.feed(byte_str)
#      71             if not state:
#      72                 continue
#
# /usr/local/lib/python3.10/dist-packages/chardet/sbcharsetprober.py in feed(self, byte_str)
#      95         # TODO: Make filter_international_words keep things in self.alphabet
#      96         if not self._model.keep_ascii_letters:
# ---> 97             byte_str = self.filter_international_words(byte_str)
#      98         else:
#      99             byte_str = self.remove_xml_tags(byte_str)
#
# /usr/local/lib/python3.10/dist-packages/chardet/charsetprober.py in filter_international_words(buf)
#     102             # frequencies).
#     103             last_char = word[-1:]
# --> 104             if not last_char.isalpha() and last_char < b"\x80":
#     105                 last_char = b" "
#     106             filtered.extend(last_char)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Seeing Websites which are visited and Websites from which data is succcessfully scraped.

# %%
# Visited Links
print("Visited Links are:\n")
print(visited_links)

# Scraped data from websites Links
print("\nLinks from which data is Successful Scraped are:\n")
print(success_links)

# Pdf Links
print("\nPDF Links from which data is Successful Scraped are:\n")
print(pdf_links)
# Out:
# Visited Links are:
#
# ['https://csvtu.ac.in/ew/', 'https://csvtu.ac.in/ew/downloads', 'http://csvtu.ac.in/NSS_CSVTU/', 'https://csvtu.ac.in/ew/csvtu-student-council/', 'https://csvtu.ac.in/ew/contact-us/', 'http://www.csvtu.ac.in/prev/', 'http://www.csvtu.ac.in/prev/index.htm', 'http://www.csvtu.ac.in/prev/vision.htm', 'http://www.csvtu.ac.in/prev/mission.htm', 'http://csvtu.ac.in/prev/AcadmicCalander2014_15.htm', 'http://www.csvtu.ac.in/prev/goals.htm', 'http://www.csvtu.ac.in/prev/objectives.htm', 'http://www.csvtu.ac.in/prev/faculties.htm', 'https://csvtu.ac.in/ew/enrollment-deficiencies/', 'https://csvtu.ac.in/ew/recruitment-notice-for-the-post-of-principal-professor-asst-professor-asso-professor-lecturer-under-statute-19-at-rungta-institute-of-pharmaceutical-sciences-bhilai/', 'https://csvtu.ac.in/ew/public-relations-officer/', 'https://csvtu.ac.in/ew/aicte-quality-improvement-schemeaqis-2021-22-financial-support/', 'https://csvtu.ac.in/ew/m-techm-plan-admissions-2020-at-university-teaching-departmentcsvtunewaibhilai/', 'https://csvtu.ac.in/ew/important-notification/', 'https://csvtu.ac.in/ew/2021/12/', 'https://csvtu.ac.in/ew/2021/08
://csvtu.ac.in/ew/university-teaching-department-diploma-in-mining-engineering/', 'https://csvtu.ac.in/ew/university-teaching-department-industrial-safety-fire-safety-engineering/', 'https://csvtu.ac.in/ew/university-teaching-department-2/', 'https://csvtu.ac.in/ew/department-of-structural-engineering/', 'https://csvtu.ac.in/ew/department-of-urban-planning/', 'https://csvtu.ac.in/ew/department-of-environmental-and-water-resources-engineering/', 'https://csvtu.ac.in/ew/department-of-energy-and-environmental-engineering/', 'https://csvtu.ac.in/ew/department-of-biomedical-engineering-bioinformatics/', 'https://csvtu.ac.in/ew/department-of-microelectronics-and-vlsi/', 'https://csvtu.ac.in/ew/seniority-list/', 'https://csvtu.ac.in/ew/academic-calendar/', 'https://csvtu.ac.in/ew/programs-and-schemes/', 'https://csvtu.ac.in/ew/admissions/', 'https://csvtu.ac.in/ew/merit-list/', 'https://csvtu.ac.in/ew/recruitment-2/', 'https://csvtu.ac.in/ew/research/phd-information/', 'https://csvtu.ac.in/ew/research-development-promotional-schemes/', 'https://csvtu.ac.in/ew/international-relations/', 'http://csvtu.ac.in/ew/memorandum-of-understanding-mous/', 'https://csvtu.ac.in/ew/notic ...
#
# PDF Links from which data is Successful Scraped are:
#
# []

# %%
Visited_file = 'Visited Links.txt'
Success_file = 'Success Links.txt'

# Open the output file for writing
with open(Visited_file, 'w') as vlink:
    # Write the combined content to the output file
    for l in visited_links:
      vlink.write(l + "\n")

# Open the output file for writing
with open(Success_file, 'w') as slink:
    # Write the combined content to the output file
    for l in success_links:
      slink.write(l + "\n")

# %% [markdown]
# ## Finding Links

# %%
# Module to match string
import re

# Reading text file
# Open the output file for writing
with open('/content/Visited Links.txt', 'r') as f:
    # Write the content to text
    text += f.read()

# Storing Text into input_string
input_string = text

# Extract links using regular expression
links = re.findall(r'https?://\S+', str(input_string))

# Combine links into a single string
combined_links = ' '.join(links)

# Separate links based on the pattern 'http' or 'https'
separated_links = re.split(r'https?://', combined_links)

# Filter out empty strings
filtered_links = [link.strip() for link in separated_links if link.strip()]

# Store links in a text file
output_file_path = 'links.txt'
with open(output_file_path, 'w') as file:
    for link in filtered_links:
        file.write('https://' + link + '\n')

print(f"Links extracted and stored in {output_file_path}")
# Out:
# Links extracted and stored in links.txt

# %%
visited_links = []
success_links = []

with open('/content/Visited Links.txt', 'r') as f:
  visited_links += f.read().splitlines()

with open('/content/Success Links.txt', 'r') as f:
  success_links += f.read().splitlines()

print("Total Number of Links visited are: ", len(visited_links))
print("\nTotal Number of Links from which data is Successfully Scraped are: ", len(success_links))
# Out:
# Total Number of Links visited are:  3156
#
# Total Number of Links from which data is Successfully Scraped are:  3156

# %%
# Removing PDF link as data from PDF was not successfully scraped
for l in visited_links:
  if l.endswith('pdf'):
    visited_links.remove(l)

for s in success_links:
  if s.endswith('pdf'):
    success_links.remove(s)

print("Total Number of Links visited are: ", len(visited_links))
print("\nTotal Number of Links from which data is Successfully Scraped are: ", len(success_links))
# Out:
# Total Number of Links visited are:  3080
#
# Total Number of Links from which data is Successfully Scraped are:  3080
